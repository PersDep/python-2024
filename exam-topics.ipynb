# %% [markdown]
# ### Темы для экзамена по Python в формате контеста
#
# 1. Базовый синтаксис. Переменные и типы данных
# 2. Ветвление и циклы
# 3. Встроенные структуры данных и их методы
# 4. Функции
# 5. Основы тестирования и обработка исключений
# 6. Способы работы с файлами
# 7. Основы ООП
# 8. Анализ данных с помощью библиотек Numpy, Pandas, Matplotlib
# 9. Базовые алгоритмы
